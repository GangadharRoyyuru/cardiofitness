# %%
import numpy as np
import matplotlib as plt
import seaborn as sns
import pandas as pd
from scipy import stats

# %%
df = pd.read_csv("C:\\Users\\lenovo\\Desktop\\CardioGoodFitness-1.csv")
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
sns.relplot(x ='Age' , y = 'Income', data = df)

# %%
sns.relplot(x ='Age' , y = 'Income', data = df, hue = "MaritalStatus")

# %%
sns.relplot(x ='Age' , y = 'Income', data = df, hue = "Fitness")

# %%
sns.relplot(x ='Age' , y = 'Income', data = df, hue = "MaritalStatus", size = "Fitness")

# %%
sns.relplot(x ='Age' , y = 'Income', data = df, hue = "Fitness", sizes = (15,200))

# %%
sns.catplot(x="MaritalStatus", y="Income", data=df)

# %%
sns.relplot(x="MaritalStatus", y="Income", data=df , hue = 'Gender')

# %%
sns.catplot(x="MaritalStatus", y="Income", data=df, jitter = False)

# %%
sns.catplot(x="MaritalStatus", y="Income", data=df, hue = "Gender")

# %%
sns.catplot(x="MaritalStatus", y="Income", data=df, kind = "swarm")

# %%
sns.catplot(x="MaritalStatus", y="Income", data=df, kind = "swarm", hue ="Gender")

# %%
sns.catplot(x="MaritalStatus", y="Income", data=df, kind = "box", hue ="Gender")

# %%
sns.catplot(x="MaritalStatus", y="Income", data=df, kind = "violin", hue ="Gender")

# %%
sns.catplot(x="MaritalStatus", y="Income", data=df, kind = "violin", hue ="Gender",split = True)

# %%
sns.catplot(x="MaritalStatus", y="Income", data=df, kind = "bar",hue ="Gender")

# %%
sns.catplot(x="MaritalStatus", y="Income", data=df,hue ="Gender",  kind = 'point')

# %%
sns.catplot(x="MaritalStatus", y="Income", data=df, kind = "swarm",hue ="Fitness", col = "Gender")

# %%
sns.distplot(df.Age)
# Out:
# D:\myfolder\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.displot(df.Age)

# %%
sns.displot(df.Age, kde = False, rug = True)

# %%
sns.displot(df.Age, kde = True, rug = True)

# %%
sns.jointplot(x = "Age", y = "Income",data = df)

# %%
sns.jointplot(x = "Age", y = "Income",data = df, hue ='Gender')

# %%
sns.catplot(x="Income",y = 'MaritalStatus', data=df, kind= "box", hue = 'Gender')

# %%
sns.jointplot(x="Age", y='Income', data=df, kind = "hex")

# %%
sns.jointplot(x="Age", y='Income', data=df, kind = "kde")

# %%
sns.catplot(x = 'Age', y = 'Income', kind = 'box',hue ="Gender", data = df, height = 5, aspect = 2.7)

# %%
sns.pairplot(df)
